# %% [markdown]
# ### API Open Weather

# %%
import requests
from dotenv import load_dotenv
import os
import re
import pandas as pd
import json
from pandas import json_normalize

# %% [markdown]
# ## Import the DataFrame and getting the access token

# %%
# Reading the files
weather_climbing_data=pd.read_csv("weather_climbing_clean.csv")

# %%
load_dotenv()
# Out:
# True

# %%
op_token= os.getenv("OPEN_WEATHER_TOKEN")

# %% [markdown]
# ## Making requests to the API

# %%
# Wheather at the exact moment 8-11-2020 17:00
response=requests.get(f"http://api.openweathermap.org/data/2.5/weather?lat=46.879967&lon=-121.726906&appid={op_token}")

# %%
data=json.loads(response.text)

# %%
print(data)
# Out:
# {'coord': {'lon': -121.73, 'lat': 46.88}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 273.99, 'feels_like': 270.62, 'temp_min': 270.37, 'temp_max': 276.48, 'pressure': 1024, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.94, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1604945219, 'sys': {'type': 1, 'id': 5366, 'country': 'US', 'sunrise': 1604934127, 'sunset': 1604968775}, 'timezone': -28800, 'id': 5806769, 'name': 'Pierce', 'cod': 200}

# %% [markdown]
# ### Obtaining the data with Onecall Option

# %%
'''A more useful way of getting the data with Onecall.
Shows the weather for day 08/11/2020 at 17:00, minute fortcast for 1 hour, hourly forecast, daily forecast 7 days and the
historical weather for the 5 previous days. '''

api_key = f"{op_token}"
lat = "46.879967"
lon = "-121.726906"
url = "https://api.openweathermap.org/data/2.5/onecall?lat=%s&lon=%s&appid=%s&units=metric" % (lat, lon, api_key)
dt="1604361600"

response = requests.get(url)
data = json.loads(response.text)
print(data)
# Out:
# {'lat': 46.88, 'lon': -121.73, 'timezone': 'America/Los_Angeles', 'timezone_offset': -28800, 'current': {'dt': 1604945393, 'sunrise': 1604934127, 'sunset': 1604968775, 'temp': 0.77, 'feels_like': -2.7, 'pressure': 1024, 'humidity': 93, 'dew_point': -0.2, 'uvi': 1.45, 'clouds': 75, 'visibility': 10000, 'wind_speed': 2.08, 'wind_deg': 267, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}, 'minutely': [{'dt': 1604945400, 'precipitation': 0}, {'dt': 1604945460, 'precipitation': 0}, {'dt': 1604945520, 'precipitation': 0}, {'dt': 1604945580, 'precipitation': 0}, {'dt': 1604945640, 'precipitation': 0}, {'dt': 1604945700, 'precipitation': 0}, {'dt': 1604945760, 'precipitation': 0}, {'dt': 1604945820, 'precipitation': 0}, {'dt': 1604945880, 'precipitation': 0}, {'dt': 1604945940, 'precipitation': 0}, {'dt': 1604946000, 'precipitation': 0}, {'dt': 1604946060, 'precipitation': 0}, {'dt': 1604946120, 'precipitation': 0}, {'dt': 1604946180, 'precipitation': 0}, {'dt': 1604946240, 'precipitation': 0}, {'dt': 1604946300, 'precipitation': 0}, {'dt': 1604946360, 'precipitation': 0}, {'dt': 1604946420, 'precipitation': 0}, {'dt': 1604946480, 'precipitation': 0}, {'dt': 1604946540, 'precipitation': 0}, {'dt': 1604946600, 'precipitation': 0}, {'dt': 1604946660, 'precipitation': 0}, {'dt': 1604946720, 'precipitation': 0}, {'dt': 1604946780, 'precipitation': 0}, {'dt': 1604946840, 'precipitation': 0}, {'dt': 1604946900, 'precipitation': 0}, {'dt': 1604946960, 'precipitation': 0}, {'dt': 1604947020, 'precipitation': 0}, {'dt': 1604947080, 'precipitation': 0}, {'dt': 1604947140, 'precipitation': 0}, {'dt': 1604947200, 'precipitation': 0}, {'dt': 1604947260, 'precipitation': 0}, {'dt': 1604947320, 'precipitation': 0}, {'dt': 1604947380, 'precipitation': 0}, {'dt': 1604947440, 'precipitation': 0}, {'dt': 1604947500, 'precipitation': 0}, {'dt': 1604947560, 'precipitation': 0}, {'dt': 1604947620, 'precipitation': 0}, {'dt': 1604947680, 'precipitation': 0}, {'dt': 1604947740, 'precipitation': 0}, {'dt': 1604947800, 'precipitation': 0}, {'dt': 1604947860, 'precipitation': 0}, {'dt': 1604947920, 'precipitation': 0}, {'dt': 1604947980, 'precipitation': 0}, {'dt': 1604948040, 'precipitation': 0}, {'dt': 1604948100, 'precipitation': 0}, {'dt': 1604948160, 'precipitation': 0}, {'dt': 1604948220, 'precipitation': 0}, {'dt': 1604948280, 'precipitation': 0}, {'dt': 1604948340, 'precipitation': 0}, {'dt': 1604948400, 'precipitation': 0}, {'dt': 1604948460, 'precipitation': 0}, {'dt': 1604948520, 'precipitation': 0}, {'dt': 1604948580, 'precipitation': 0}, {'dt': 1604948640, 'precipitation': 0}, {'dt': 1604948700, 'precipitation': 0}, {'dt': 1604948760, 'precipitation': 0}, {'dt': 1604948820, 'precipitation': 0}, {'dt': 1604948880, 'precipitation': 0}, {'dt': 1604948940, 'precipitation': 0}, {'dt': 1604949000, 'precipitation': 0}], 'hourly': [{'dt': 1604944800, 'temp': 0.77, 'feels_like': -2.7, 'pressure': 1024, 'humidity': 93, 'dew_point': -0.2, 'clouds': 75, 'visibility': 10000, 'wind_speed': 2.08, 'wind_deg': 267, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1604948400, 'temp': -3.87, 'feels_like': -8.01, 'pressure': 1023, 'humidity': 90, 'dew_point': -5.11, 'clouds': 87, 'visibility': 10000, 'wind_speed': 2.15, 'wind_deg': 268, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1604952000, 'temp': -7.23, 'feels_like': -11.65, 'pressure': 1022, 'humidity': 92, 'dew_point': -8.19, 'clouds': 95, 'visibility': 6429, 'wind_speed': 2.14, 'wind_deg': 269, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1604955600, 'temp': -8.8, 'feels_like': -13.21, 'pressure': 1021, 'humidity': 93, 'dew_point': -9.62, 'clouds': 98, 'visibility': 10000, 'wind_speed': 1.96, 'wind_deg': 263, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast cloud ...

# %%
# Obtain the temperatures from 8 Nov to 15 Nov 2020
temps=[]
days=[]
daily = data["daily"]

for entry in daily:
    temp = entry["temp"]
    day= entry["dt"]
    temps.append(temp)
    days.append(dt)

print(temps)
print(days)
# Out:
# [{'day': 0.77, 'min': -12.49, 'max': 0.77, 'night': -9.17, 'eve': -8.14, 'morn': -12.46}, {'day': -10.26, 'min': -12.93, 'max': -9.57, 'night': -12.93, 'eve': -9.95, 'morn': -10.75}, {'day': -11.15, 'min': -15.78, 'max': -10.29, 'night': -15.48, 'eve': -11.93, 'morn': -15.78}, {'day': -9.86, 'min': -15.38, 'max': -8.82, 'night': -13.48, 'eve': -10.37, 'morn': -15.38}, {'day': -9.22, 'min': -14.03, 'max': -8.1, 'night': -9.43, 'eve': -9.18, 'morn': -13.41}, {'day': -10.31, 'min': -11.13, 'max': -9.26, 'night': -10.82, 'eve': -11.06, 'morn': -9.26}, {'day': -9.15, 'min': -10.64, 'max': -9.11, 'night': -9.69, 'eve': -9.32, 'morn': -10.38}, {'day': -9.59, 'min': -10.55, 'max': -9.12, 'night': -10.55, 'eve': -9.92, 'morn': -9.69}]
# ['1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600']

# %%
# Obtain the humidity from 8 Nov to 15 Nov 2020
humidity=[]
days=[]
daily = data["daily"]

for entry in daily:
    hum = entry["humidity"]
    day= entry["dt"]
    humidity.append(hum)
    days.append(dt)
print(humidity)
print(days)
# Out:
# [93, 100, 100, 100, 100, 100, 100, 100]
# ['1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600']

# %%
# Obtain the wind speed from 8 Nov to 15 Nov 2020
wind_s=[]
days=[]
daily = data["daily"]

for entry in daily:
    wind = entry["wind_speed"]
    day= entry["dt"]
    wind_s.append(wind)
    days.append(dt)
print(wind_s)
print(days)
# Out:
# [2.08, 3.24, 1.02, 0.98, 1.42, 6.85, 2.2, 1.5]
# ['1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600', '1604361600']

# %% [markdown]
# The data for solar radiation and wind direction can not be obtained with this API

# %%
# Collecting the temperature for each day from 8 Nov to 15 Nov 2020

df = pd.json_normalize(data["daily"][0]["temp"])
print (df)
df1= pd.json_normalize(data["daily"][1]["temp"])
print(df1)
df2 = pd.json_normalize(data["daily"][2]["temp"])
print (df2)
df3= pd.json_normalize(data["daily"][3]["temp"])
print(df3)
df4 = pd.json_normalize(data["daily"][4]["temp"])
print (df4)
df5= pd.json_normalize(data["daily"][5]["temp"])
print(df5)
df6 = pd.json_normalize(data["daily"][6]["temp"])
print (df6)
df7= pd.json_normalize(data["daily"][7]["temp"])
print(df7)
# Out:
#     day    min   max  night   eve   morn
# 0  0.77 -12.49  0.77  -9.17 -8.14 -12.46
#      day    min   max  night   eve   morn
# 0 -10.26 -12.93 -9.57 -12.93 -9.95 -10.75
#      day    min    max  night    eve   morn
# 0 -11.15 -15.78 -10.29 -15.48 -11.93 -15.78
#     day    min   max  night    eve   morn
# 0 -9.86 -15.38 -8.82 -13.48 -10.37 -15.38
#     day    min  max  night   eve   morn
# 0 -9.22 -14.03 -8.1  -9.43 -9.18 -13.41
#      day    min   max  night    eve  morn
# 0 -10.31 -11.13 -9.26 -10.82 -11.06 -9.26
#     day    min   max  night   eve   morn
# 0 -9.15 -10.64 -9.11  -9.69 -9.32 -10.38
#     day    min   max  night   eve  morn
# 0 -9.59 -10.55 -9.12 -10.55 -9.92 -9.69

# %%
# Concateneting in a dataframe all the data from temperature
result = pd.concat([df,df1, df2, df3, df4, df5, df6, df7])
result
# Out:
#      day    min    max  night    eve   morn
# 0   0.77 -12.49   0.77  -9.17  -8.14 -12.46
# 0 -10.26 -12.93  -9.57 -12.93  -9.95 -10.75
# 0 -11.15 -15.78 -10.29 -15.48 -11.93 -15.78
# 0  -9.86 -15.38  -8.82 -13.48 -10.37 -15.38
# 0  -9.22 -14.03  -8.10  -9.43  -9.18 -13.41
# 0 -10.31 -11.13  -9.26 -10.82 -11.06  -9.26
# 0  -9.15 -10.64  -9.11  -9.69  -9.32 -10.38
# 0  -9.59 -10.55  -9.12 -10.55  -9.92  -9.69

# %%
# Adding a Date column to specify the date of each of the measurements
result["Date"]=["08/11/2020", "09/11/2020", "10/11/2020", "11/11/2020", "12/11/2020", "13/11/2020", "14/11/2020", "15/11/2020"]
result
# Out:
#      day    min    max  night    eve   morn        Date
# 0   0.77 -12.49   0.77  -9.17  -8.14 -12.46  08/11/2020
# 0 -10.26 -12.93  -9.57 -12.93  -9.95 -10.75  09/11/2020
# 0 -11.15 -15.78 -10.29 -15.48 -11.93 -15.78  10/11/2020
# 0  -9.86 -15.38  -8.82 -13.48 -10.37 -15.38  11/11/2020
# 0  -9.22 -14.03  -8.10  -9.43  -9.18 -13.41  12/11/2020
# 0 -10.31 -11.13  -9.26 -10.82 -11.06  -9.26  13/11/2020
# 0  -9.15 -10.64  -9.11  -9.69  -9.32 -10.38  14/11/2020
# 0  -9.59 -10.55  -9.12 -10.55  -9.92  -9.69  15/11/2020

# %%
# Collecting the temperature for each day from 8 Nov to 15 Nov 2020

dict_0 = {"humidity" : data["daily"][0]["humidity"], "wind_speed": data["daily"][0]["wind_speed"] }
dict_1 = {"humidity" : data["daily"][1]["humidity"], "wind_speed": data["daily"][1]["wind_speed"] }
dict_2 = {"humidity" : data["daily"][2]["humidity"], "wind_speed": data["daily"][2]["wind_speed"] }
dict_3 = {"humidity" : data["daily"][3]["humidity"], "wind_speed": data["daily"][3]["wind_speed"] }
dict_4 = {"humidity" : data["daily"][4]["humidity"], "wind_speed": data["daily"][4]["wind_speed"] }
dict_5 = {"humidity" : data["daily"][5]["humidity"], "wind_speed": data["daily"][5]["wind_speed"] }
dict_6 = {"humidity" : data["daily"][6]["humidity"], "wind_speed": data["daily"][6]["wind_speed"] }
dict_7 = {"humidity" : data["daily"][7]["humidity"], "wind_speed": data["daily"][7]["wind_speed"] }

df0hw = pd.json_normalize(dict_0)
df1hw = pd.json_normalize(dict_1)
df2hw = pd.json_normalize(dict_2)
df3hw = pd.json_normalize(dict_3)
df4hw = pd.json_normalize(dict_4)
df5hw = pd.json_normalize(dict_5)
df6hw = pd.json_normalize(dict_6)
df7hw = pd.json_normalize(dict_7)

result_h_w = pd.concat([df0hw,df1hw, df2hw, df3hw, df4hw, df5hw, df6hw, df7hw])
result_h_w
# Out:
#    humidity  wind_speed
# 0        93        2.08
# 0       100        3.24
# 0       100        1.02
# 0       100        0.98
# 0       100        1.42
# 0       100        6.85
# 0       100        2.20
# 0       100        1.50

# %%
# COncatenate the values of both tables
joined_thw = pd.concat([result, result_h_w], axis=1)
joined_thw
# Out:
#      day    min    max  night    eve   morn        Date  humidity  wind_speed
# 0   0.77 -12.49   0.77  -9.17  -8.14 -12.46  08/11/2020        93        2.08
# 0 -10.26 -12.93  -9.57 -12.93  -9.95 -10.75  09/11/2020       100        3.24
# 0 -11.15 -15.78 -10.29 -15.48 -11.93 -15.78  10/11/2020       100        1.02
# 0  -9.86 -15.38  -8.82 -13.48 -10.37 -15.38  11/11/2020       100        0.98
# 0  -9.22 -14.03  -8.10  -9.43  -9.18 -13.41  12/11/2020       100        1.42
# 0 -10.31 -11.13  -9.26 -10.82 -11.06  -9.26  13/11/2020       100        6.85
# 0  -9.15 -10.64  -9.11  -9.69  -9.32 -10.38  14/11/2020       100        2.20
# 0  -9.59 -10.55  -9.12 -10.55  -9.92  -9.69  15/11/2020       100        1.50

# %%
# Giving an index to the rows of the table
s = pd.Series([0, 1, 2, 3, 4, 5, 6, 7])
joined_thw.set_index([s])
# Out:
#      day    min    max  night    eve   morn        Date  humidity  wind_speed
# 0   0.77 -12.49   0.77  -9.17  -8.14 -12.46  08/11/2020        93        2.08
# 1 -10.26 -12.93  -9.57 -12.93  -9.95 -10.75  09/11/2020       100        3.24
# 2 -11.15 -15.78 -10.29 -15.48 -11.93 -15.78  10/11/2020       100        1.02
# 3  -9.86 -15.38  -8.82 -13.48 -10.37 -15.38  11/11/2020       100        0.98
# 4  -9.22 -14.03  -8.10  -9.43  -9.18 -13.41  12/11/2020       100        1.42
# 5 -10.31 -11.13  -9.26 -10.82 -11.06  -9.26  13/11/2020       100        6.85
# 6  -9.15 -10.64  -9.11  -9.69  -9.32 -10.38  14/11/2020       100        2.20
# 7  -9.59 -10.55  -9.12 -10.55  -9.92  -9.69  15/11/2020       100        1.50

# %%
# Rename the columns as in the cleaned DataFrame
joined_clean=joined_thw.rename(columns={"day": "Temperature AVG"})
joined_clean1=joined_clean.rename(columns={"humidity": "Relative Humidity AVG"})
joined_clean2=joined_clean1.rename(columns={"wind_speed": "Wind Speed Daily AVG"})

joined_clean2
# Out:
#    Temperature AVG    min    max  night    eve   morn        Date  \
# 0             0.77 -12.49   0.77  -9.17  -8.14 -12.46  08/11/2020
# 0           -10.26 -12.93  -9.57 -12.93  -9.95 -10.75  09/11/2020
# 0           -11.15 -15.78 -10.29 -15.48 -11.93 -15.78  10/11/2020
# 0            -9.86 -15.38  -8.82 -13.48 -10.37 -15.38  11/11/2020
# 0            -9.22 -14.03  -8.10  -9.43  -9.18 -13.41  12/11/2020
# 0           -10.31 -11.13  -9.26 -10.82 -11.06  -9.26  13/11/2020
# 0            -9.15 -10.64  -9.11  -9.69  -9.32 -10.38  14/11/2020
# 0            -9.59 -10.55  -9.12 -10.55  -9.92  -9.69  15/11/2020
#
#    Relative Humidity AVG  Wind Speed Daily AVG
# 0                     93                  2.08
# 0                    100                  3.24
# 0                    100                  1.02
# 0                    100                  0.98
# 0                    100                  1.42
# 0                    100                  6.85
# 0                    100                  2.20
# 0                    100                  1.50

# %%
# Delete the not useful columns
joined_clean3=joined_clean2.drop(labels=["min", "max", "night", "eve", "morn"], axis=1)
joined_clean3
# Out:
#    Temperature AVG        Date  Relative Humidity AVG  Wind Speed Daily AVG
# 0             0.77  08/11/2020                     93                  2.08
# 0           -10.26  09/11/2020                    100                  3.24
# 0           -11.15  10/11/2020                    100                  1.02
# 0            -9.86  11/11/2020                    100                  0.98
# 0            -9.22  12/11/2020                    100                  1.42
# 0           -10.31  13/11/2020                    100                  6.85
# 0            -9.15  14/11/2020                    100                  2.20
# 0            -9.59  15/11/2020                    100                  1.50

# %%
# Changing from miles/hour to kilometers/hour the wind speed

def m_km(miles):
    km= 1.60934 * miles
    return km

joined_clean3["Wind Speed Daily AVG"]= joined_clean3["Wind Speed Daily AVG"].apply(m_km)
joined_clean3
# Out:
#    Temperature AVG        Date  Relative Humidity AVG  Wind Speed Daily AVG
# 0             0.77  08/11/2020                     93              3.347427
# 0           -10.26  09/11/2020                    100              5.214262
# 0           -11.15  10/11/2020                    100              1.641527
# 0            -9.86  11/11/2020                    100              1.577153
# 0            -9.22  12/11/2020                    100              2.285263
# 0           -10.31  13/11/2020                    100             11.023979
# 0            -9.15  14/11/2020                    100              3.540548
# 0            -9.59  15/11/2020                    100              2.414010

# %% [markdown]
# ## Join the data of the previos DataFrame from data cleaning to this new DataFrame

# %%
weather_climbing_data
# Out:
#       Unnamed: 0        Date                   Route  Attempted  Succeeded  \
# 0              0  11/27/2015  Disappointment Cleaver          2          0
# 1              1  11/21/2015  Disappointment Cleaver          3          0
# 2              2  10/15/2015  Disappointment Cleaver          2          0
# 3              3  10/13/2015           Little Tahoma          8          0
# 4              4   10/9/2015  Disappointment Cleaver          2          0
# ...          ...         ...                     ...        ...        ...
# 4072        4072   1/16/2014           Little Tahoma          2          0
# 4073        4073    1/6/2014  Disappointment Cleaver          8          0
# 4074        4074    1/6/2014  Disappointment Cleaver          8          0
# 4075        4075    1/5/2014  Disappointment Cleaver          2          0
# 4076        4076    1/4/2014        Gibralter Ledges          3          2
#
#       Success Percentage  Battery Voltage AVG  Temperature AVG  \
# 0               0.000000            13.643750        -3.154630
# 1               0.000000            13.749583        -0.388889
# 2               0.000000            13.461250         8.026620
# 3               0.000000            13.532083         4.988657
# 4               0.000000            13.216250         3.478009
# ...                  ...                  ...              ...
# 4072            0.000000                  NaN              NaN
# 4073            0.000000                  NaN              NaN
# 4074            0.000000                  NaN              NaN
# 4075            0.000000                  NaN              NaN
# 4076            0.666667                  NaN              NaN
#
#       Relative Humidity AVG  Wind Speed Daily AVG  Wind Direction AVG  \
# 0                 19.715000             44.803355           68.004167
# 1                 21.690708              3.614309          117.549667
# 2                 27.211250             27.622108          259.121375
# 3                 28.335708             31.528848          279.779167
# 4                 74.329167            104.829725          264.687500
# ...                     ...                   ...                 ...
# 4072                    NaN                   NaN                 NaN
# 4073                    NaN                   NaN                 NaN
# 4074                    NaN                   NaN                 NaN
# 4075                    NaN                   NaN                 NaN
# 4076                    NaN                   NaN                 NaN
#
#       Solare Radiation AVG  Year  Month
# 0                88.496250  2015     11
# 1                93.660417  2015     11
# 2               138.387000  2015     10
# 3               176.382667  2015     10
# 4                27.791292  2015     10
# ...                    ...   ...    ...
# 4072                   NaN  2014      1
# 4073                   NaN  2014      1
# 4074                   NaN  2014      1
# 4075                   NaN  2014      1
# 4076                   NaN  2014      1
#
# [4077 rows x 14 columns]

# %%
# # Insert the new values in the table from data cleaning
cleaned_df=weather_climbing_data.append(joined_clean3)
cleaned_df
# Out:
#     Unnamed: 0        Date                   Route  Attempted  Succeeded  \
# 0          0.0  11/27/2015  Disappointment Cleaver        2.0        0.0
# 1          1.0  11/21/2015  Disappointment Cleaver        3.0        0.0
# 2          2.0  10/15/2015  Disappointment Cleaver        2.0        0.0
# 3          3.0  10/13/2015           Little Tahoma        8.0        0.0
# 4          4.0   10/9/2015  Disappointment Cleaver        2.0        0.0
# ..         ...         ...                     ...        ...        ...
# 0          NaN  11/11/2020                     NaN        NaN        NaN
# 0          NaN  12/11/2020                     NaN        NaN        NaN
# 0          NaN  13/11/2020                     NaN        NaN        NaN
# 0          NaN  14/11/2020                     NaN        NaN        NaN
# 0          NaN  15/11/2020                     NaN        NaN        NaN
#
#     Success Percentage  Battery Voltage AVG  Temperature AVG  \
# 0                  0.0            13.643750        -3.154630
# 1                  0.0            13.749583        -0.388889
# 2                  0.0            13.461250         8.026620
# 3                  0.0            13.532083         4.988657
# 4                  0.0            13.216250         3.478009
# ..                 ...                  ...              ...
# 0                  NaN                  NaN        -9.860000
# 0                  NaN                  NaN        -9.220000
# 0                  NaN                  NaN       -10.310000
# 0                  NaN                  NaN        -9.150000
# 0                  NaN                  NaN        -9.590000
#
#     Relative Humidity AVG  Wind Speed Daily AVG  Wind Direction AVG  \
# 0               19.715000             44.803355           68.004167
# 1               21.690708              3.614309          117.549667
# 2               27.211250             27.622108          259.121375
# 3               28.335708             31.528848          279.779167
# 4               74.329167            104.829725          264.687500
# ..                    ...                   ...                 ...
# 0              100.000000              1.577153                 NaN
# 0              100.000000              2.285263                 NaN
# 0              100.000000             11.023979                 NaN
# 0              100.000000              3.540548                 NaN
# 0              100.000000              2.414010                 NaN
#
#     Solare Radiation AVG    Year  Month
# 0              88.496250  2015.0   11.0
# 1              93.660417  2015.0   11.0
# 2             138.387000  2015.0   10.0
# 3             176.382667  2015.0   10.0
# 4              27.791292  2015.0   10.0
# ..                   ...     ...    ...
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
#
# [4085 rows x 14 columns]

# %%
# Delete column "Unnamed:0"
cleaned_df=cleaned_df.drop(labels="Unnamed: 0", axis=1)
cleaned_df
# Out:
#           Date                   Route  Attempted  Succeeded  \
# 0   11/27/2015  Disappointment Cleaver        2.0        0.0
# 1   11/21/2015  Disappointment Cleaver        3.0        0.0
# 2   10/15/2015  Disappointment Cleaver        2.0        0.0
# 3   10/13/2015           Little Tahoma        8.0        0.0
# 4    10/9/2015  Disappointment Cleaver        2.0        0.0
# ..         ...                     ...        ...        ...
# 0   11/11/2020                     NaN        NaN        NaN
# 0   12/11/2020                     NaN        NaN        NaN
# 0   13/11/2020                     NaN        NaN        NaN
# 0   14/11/2020                     NaN        NaN        NaN
# 0   15/11/2020                     NaN        NaN        NaN
#
#     Success Percentage  Battery Voltage AVG  Temperature AVG  \
# 0                  0.0            13.643750        -3.154630
# 1                  0.0            13.749583        -0.388889
# 2                  0.0            13.461250         8.026620
# 3                  0.0            13.532083         4.988657
# 4                  0.0            13.216250         3.478009
# ..                 ...                  ...              ...
# 0                  NaN                  NaN        -9.860000
# 0                  NaN                  NaN        -9.220000
# 0                  NaN                  NaN       -10.310000
# 0                  NaN                  NaN        -9.150000
# 0                  NaN                  NaN        -9.590000
#
#     Relative Humidity AVG  Wind Speed Daily AVG  Wind Direction AVG  \
# 0               19.715000             44.803355           68.004167
# 1               21.690708              3.614309          117.549667
# 2               27.211250             27.622108          259.121375
# 3               28.335708             31.528848          279.779167
# 4               74.329167            104.829725          264.687500
# ..                    ...                   ...                 ...
# 0              100.000000              1.577153                 NaN
# 0              100.000000              2.285263                 NaN
# 0              100.000000             11.023979                 NaN
# 0              100.000000              3.540548                 NaN
# 0              100.000000              2.414010                 NaN
#
#     Solare Radiation AVG    Year  Month
# 0              88.496250  2015.0   11.0
# 1              93.660417  2015.0   11.0
# 2             138.387000  2015.0   10.0
# 3             176.382667  2015.0   10.0
# 4              27.791292  2015.0   10.0
# ..                   ...     ...    ...
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
# 0                    NaN     NaN    NaN
#
# [4085 rows x 13 columns]

# %%
# Add the year and month from the new entries to their respective columns
cleaned_df['Year'] = pd.DatetimeIndex(cleaned_df['Date']).year
cleaned_df['Month'] = pd.DatetimeIndex(cleaned_df['Date']).month
cleaned_df
# Out:
#           Date                   Route  Attempted  Succeeded  \
# 0   11/27/2015  Disappointment Cleaver        2.0        0.0
# 1   11/21/2015  Disappointment Cleaver        3.0        0.0
# 2   10/15/2015  Disappointment Cleaver        2.0        0.0
# 3   10/13/2015           Little Tahoma        8.0        0.0
# 4    10/9/2015  Disappointment Cleaver        2.0        0.0
# ..         ...                     ...        ...        ...
# 0   11/11/2020                     NaN        NaN        NaN
# 0   12/11/2020                     NaN        NaN        NaN
# 0   13/11/2020                     NaN        NaN        NaN
# 0   14/11/2020                     NaN        NaN        NaN
# 0   15/11/2020                     NaN        NaN        NaN
#
#     Success Percentage  Battery Voltage AVG  Temperature AVG  \
# 0                  0.0            13.643750        -3.154630
# 1                  0.0            13.749583        -0.388889
# 2                  0.0            13.461250         8.026620
# 3                  0.0            13.532083         4.988657
# 4                  0.0            13.216250         3.478009
# ..                 ...                  ...              ...
# 0                  NaN                  NaN       -10.100000
# 0                  NaN                  NaN        -8.920000
# 0                  NaN                  NaN       -10.080000
# 0                  NaN                  NaN        -9.060000
# 0                  NaN                  NaN        -9.580000
#
#     Relative Humidity AVG  Wind Speed Daily AVG  Wind Direction AVG  \
# 0               19.715000             44.803355           68.004167
# 1               21.690708              3.614309          117.549667
# 2               27.211250             27.622108          259.121375
# 3               28.335708             31.528848          279.779167
# 4               74.329167            104.829725          264.687500
# ..                    ...                   ...                 ...
# 0              100.000000              3.548266                 NaN
# 0              100.000000              2.434577                 NaN
# 0              100.000000             20.512604                 NaN
# 0              100.000000              5.179950                 NaN
# 0              100.000000              2.900772                 NaN
#
#     Solare Radiation AVG  Year  Month
# 0              88.496250  2015     11
# 1              93.660417  2015     11
# 2             138.387000  2015     10
# 3             176.382667  2015     10
# 4              27.791292  2015     10
# ..                   ...   ...    ...
# 0                    NaN  2020     11
# 0                    NaN  2020     12
# 0                    NaN  2020     11
# 0                    NaN  2020     11
# 0                    NaN  2020     11
#
# [4085 rows x 13 columns]

# %% [markdown]
# ## Export the cleaned DataFrame

# %%
cleaned_df.to_csv("API_info_clean.csv")
